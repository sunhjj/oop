# %% [markdown]
# # matplotlib

# %%
import matplotlib
matplotlib.rcParams['font.family'] = 'AppleGothic'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
import pandas as pd
df = pd.read_excel('output.xlsx')
df.head()
# Out:
#    N       종목명     현재가    전일비   등락률   액면가     시가총액    상장주식수  외국인비율      거래량
# 0  1      삼성전자   65100   -300 -0.46   100  3886328  5969783  51.93  9763209  \
# 1  2  LG에너지솔루션  564000  -3000 -0.53   500  1319760   234000   5.37   243140
# 2  3    SK하이닉스   88700  -1100 -1.22  5000   645738   728002  49.65  1775068
# 3  4  삼성바이오로직스  797000  22000  2.84  2500   567257    71174  10.62   144166
# 4  5      LG화학  731000   5000  0.69  5000   516030    70592  48.36   143423
#
#       PER    ROE
# 0    8.08  17.07
# 1  170.65   5.75
# 2   28.96   3.56
# 3   69.84  11.42
# 4   31.01   6.95

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeFourSym',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'cmr10',
#  'STIXSizeThreeSym',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'cmss10',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'STIXGeneral',
#  'STIXSizeFourSym',
#  'STIXGeneral',
#  'cmsy10',
#  'STIXSizeFiveSym',
#  'STIXSizeOneSym',
#  'DejaVu Serif Display',
#  'cmtt10',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'STIXSizeOneSym',
#  'cmmi10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXNonUnicode',
#  'DejaVu Sans',
#  'STIXSizeTwoSym',
#  'cmb10',
#  'ITF Devanagari',
#  'Noto Sans Bamum',
#  'Tahoma',
#  'Hoefler Text',
#  'Zapf Dingbats',
#  'Palatino',
#  'STIXSizeOneSym',
#  'Andale Mono',
#  'Athelas',
#  'MesloLGS NF',
#  'Noto Sans Myanmar',
#  'Webdings',
#  'Verdana',
#  'Kefa',
# ...

# %%
df.set_index('종목명', inplace=True)
df
# Out:
#             N     현재가    전일비    등락률   액면가     시가총액    상장주식수  외국인비율      거래량
# 종목명
# 삼성전자        1   65100   -300  -0.46   100  3886328  5969783  51.93  9763209  \
# LG에너지솔루션    2  564000  -3000  -0.53   500  1319760   234000   5.37   243140
# SK하이닉스      3   88700  -1100  -1.22  5000   645738   728002  49.65  1775068
# 삼성바이오로직스    4  797000  22000   2.84  2500   567257    71174  10.62   144166
# LG화학        5  731000   5000   0.69  5000   516030    70592  48.36   143423
# 삼성SDI       6  684000      0   0.00  5000   470349    68765  49.24   174071
# 삼성전자우       7   54600   -700  -1.27   100   449296   822887  72.10   832232
# 현대차         8  199200  -1800  -0.90  5000   421371   211532  31.73   471523
# 기아          9   85900   -600  -0.69  5000   348207   405363  37.06   643781
# NAVER      10  196100   3500   1.82   100   321700   164049  47.60   897298
# POSCO홀딩스   11  379000  -1000  -0.26  5000   320525    84571  40.57   617133
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='종목명'>

# %%
df.drop('N')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 df.drop('N')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5268, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5120 def drop(
#    5121     self,
#    5122     labels: IndexLabel = None,
#    (...)
#    5129     errors: IgnoreRaise = "raise",
#    5130 ) -> DataFrame | None:
#    5131     """
#    5132     Drop specified labels from rows or columns.
#    5133
#    (...)
#    5266             weight  1.0     0.8
#    5267     """
# -> 5268     return super().drop(
#    5269         labels=labels,
#    5270         axis=axis,
#    5271         index=index,
#    5272         columns=columns,
#    5273         level=level,
#    5274         inplace=inplace,
#    5275         errors=errors,
#    5276     )
#
# ...

# %%
df.drop('N', axis=1, inplace=True)
df
# Out:
#               현재가    전일비    등락률   액면가     시가총액    상장주식수  외국인비율      거래량
# 종목명
# 삼성전자        65100   -300  -0.46   100  3886328  5969783  51.93  9763209  \
# LG에너지솔루션   564000  -3000  -0.53   500  1319760   234000   5.37   243140
# SK하이닉스      88700  -1100  -1.22  5000   645738   728002  49.65  1775068
# 삼성바이오로직스   797000  22000   2.84  2500   567257    71174  10.62   144166
# LG화학       731000   5000   0.69  5000   516030    70592  48.36   143423
# 삼성SDI      684000      0   0.00  5000   470349    68765  49.24   174071
# 삼성전자우       54600   -700  -1.27   100   449296   822887  72.10   832232
# 현대차        199200  -1800  -0.90  5000   421371   211532  31.73   471523
# 기아          85900   -600  -0.69  5000   348207   405363  37.06   643781
# NAVER      196100   3500   1.82   100   321700   164049  47.60   897298
# POSCO홀딩스   379000  -1000  -0.26  5000   320525    84571  40.57   617133
# 포스코퓨처엠     338500  -6500  -1.88   500   262213    77463   6.96  1093594
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='종목명'>

# %%
new_df = df['전일비']
new_df.info()
new_df.plot()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 50 entries, 삼성전자 to SK바이오사이언스
# Series name: 전일비
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     int64
# dtypes: int64(1)
# memory usage: 2.8+ KB
# <Axes: xlabel='종목명'>

# %%
matplotlib.rcParams['font.size'] = 8

# %%
new_df = df['전일비']
new_df.info()
new_df.plot()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 50 entries, 삼성전자 to SK바이오사이언스
# Series name: 전일비
# Non-Null Count  Dtype
# --------------  -----
# 50 non-null     int64
# dtypes: int64(1)
# memory usage: 2.8+ KB
# <Axes: xlabel='종목명'>

# %%
new_df = df[['현재가','전일비']][:10]
new_df.info()
new_df.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 삼성전자 to NAVER
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   현재가     10 non-null     int64
#  1   전일비     10 non-null     int64
# dtypes: int64(2)
# memory usage: 240.0+ bytes
# <Axes: xlabel='종목명'>

# %%
import matplotlib.pyplot as plt
new_df = df[['현재가','전일비']][:10]
plt.barh(new_df.index, new_df['현재가'])
# Out:
# <BarContainer object of 10 artists>

# %%
new_df = df[['현재가','전일비']][:10]
new_df.info()
plt.bar(new_df.index, new_df['현재가'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 삼성전자 to NAVER
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   현재가     10 non-null     int64
#  1   전일비     10 non-null     int64
# dtypes: int64(2)
# memory usage: 240.0+ bytes
# <BarContainer object of 10 artists>

# %%
new_df.index
# Out:
# Index(['삼성전자', 'LG에너지솔루션', 'SK하이닉스', '삼성바이오로직스', 'LG화학', '삼성SDI', '삼성전자우',
#        '현대차', '기아', 'NAVER'],
#       dtype='object', name='종목명')

# %%
fig, ax = plt.subplots()
ax.set_xticklabels(new_df.index, rotation=45)
plt.bar(new_df.index, new_df['현재가'])
# Out:
# /var/folders/my/tnv9yh350wl4vynk5w84w7bm0000gn/T/ipykernel_5165/1457497023.py:2: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_df.index, rotation=45)
# <BarContainer object of 10 artists>
